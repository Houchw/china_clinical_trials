# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json

plt.rcParams['font.sans-serif'] = ['simhei']

# %%
with open("trials.jl", "rb") as f:
    data = [json.loads(line.strip()) for line in f.readlines()]

df = pd.DataFrame(data)
#df.head()

# %% [markdown]
# # 数据浏览

# %%
df.columns.values #列名
# Out:
# array(['accept_id', 'accepts_healthy_volunteers', 'actual_enrollment',
#        'age', 'allocation', 'applicant', 'applicant_Email',
#        'applicant_address', 'applicant_postcode', 'applicant_telephone',
#        'conditions', 'ctr_number', 'data_management_committee',
#        'drug_name', 'drug_type', 'estimated_enrollment',
#        'ethic_committee_approved', 'ethic_committee_approved_date',
#        'ethic_committee_name', 'exclusion_criteria',
#        'experimental_drug_name', 'experimental_drug_usage',
#        'first_subject_included_date', 'gender', 'inclusion_criteria',
#        'insurance_for_subject', 'intervention_model', 'masking', 'phase',
#        'placebo_drug_name', 'placebo_drug_usage', 'plan_version',
#        'primary_outcome_measures', 'primary_outcome_measures_choice',
#        'primary_outcome_measures_date', 'public_title', 'purpose',
#        'recruitment_status', 'scientific_title',
# ...

# %%
df.sponsors.values[:50]
# Out:
# array(['华中药业股份有限公司', '广东康大制药有限公司/', '齐鲁制药有限公司', '华中药业股份有限公司',
#        '和记黄埔医药（上海）有限公司/', '浙江昂利康制药股份有限公司', '四川峨嵋山药业有限公司',
#        '深圳九瑞健康科技开发有限公司', '苏州二叶制药有限公司', '', '山东华鲁制药有限公司',
#        '苏州思坦维生物技术股份有限公司/', '北京市丰硕维康技术开发有限责任公司/', '湖北广济药业股份有限公司',
#        '珠海横琴新区中珠正泰医疗管理有限公司/复旦大学/', '宜昌东阳光长江药业股份有限公司', '浙江昂利康制药股份有限公司',
#        '江苏恒瑞医药股份有限公司/江苏恒瑞医药股份有限公司/上海恒瑞医药有限公司/', '神州细胞工程有限公司/',
#        '四川普锐特医药科技有限责任公司', '深圳科兴药业有限公司/',
#        '浙江仙琚制药股份有限公司/浙江仙琚制药股份有限公司/杭州奥默医药股份有限公司/', '石药集团中诺药业（石家庄）有限公司',
#        '成都康弘药业集团股份有限公司', '正大天晴药业集团股份有限公司/', '基石药业（苏州）有限公司/拓石药业（上海）有限公司/',
#        '深圳信立泰药业有限公司/', '花园药业股份有限公司', '天津医药集团津康制药有限公司', '上海璎黎药业有限公司/',
#        '沈阳圣元药业有限公司', '上海星泰医药科技有限公司/上海复星医药产业发展有限公司/', '北京天衡药物研究院南阳天衡制药厂/',
#        '宜昌东阳光长江药业股份有限公司', '哈尔滨华瑞生化药业有限责任公司', '北京康蒂尼药业有限公司',
#        '广东华南药业集团有限公司', '北京益民药业有限公司', '深圳市海滨制药有限公司',
#        '江苏豪森药业集团有限公司/江苏豪森药业集团有限公司/',
#        '泰州翰中生物医药有限公司/杭州翰思生物医药有限公司/中山康方生物医药有限公司/', '山东鲁抗医药股份有限公司',
# ...

# %%
df.sponsors.value_counts()[:20].plot.barh()

# %%
tmp_1.ethic_committee_approved_date = tmp_1.ethic_committee_approved_date.str.replace('年', '-')
tmp_1.ethic_committee_approved_date = tmp_1.ethic_committee_approved_date.str.replace('月', '-')
tmp_1.ethic_committee_approved_date = tmp_1.ethic_committee_approved_date.str.replace('日', '')
tmp_1.ethic_committee_approved_date = pd.to_datetime(tmp_1.ethic_committee_approved_date)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:3643: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
tmp_1.ethic_committee_approved_date.value_counts().resample('M', ).sum().truncate(before = '20130101').plot(figsize = (12, 9))

# %%
df.phase.value_counts().plot.bar()

# %%
df.intervention_model.value_counts().plot.bar()

# %%
df.study_leader_institution.value_counts()[1:21].plot.barh()

# %%
df.drug_type.value_counts().plot.bar()

# %%
df.study_leader_name.str.split('，', expand=True)[0].value_counts()[1:21].plot.bar()

# %%
df.conditions.values[:100]
# Out:
# array(['适用于敏感菌所致的急性扁桃体炎、咽峡炎、中耳炎、鼻窦炎、支气管炎、肺炎等呼吸道感染、尿路感染及皮肤软组织感染等',
#        '治疗手足口病', '适用于治疗成人伴有代偿性肝病的慢性乙型肝炎病毒(HBV)感染', '高血压和心力衰竭', '胆道癌',
#        '本品适用于金黄色葡萄球菌、溶血性链球菌、肺炎球菌、大肠杆菌、肺炎杆菌、流感杆菌、痢疾杆菌等敏感菌株引起的下列部位的轻、中度感染； 扁桃体炎、扁桃体周围炎、咽喉炎、支气管炎、肺炎、支气管肺炎、哮喘和支气管扩张感染以及手术后感染； 急性及慢性肾盂肾炎、膀胱炎、前列腺炎及泌尿生殖系统感染； 中耳炎、外耳炎、鼻窦； 上颌骨周围炎、上颌骨骨膜炎、上颌骨髓炎、急性腭炎、牙槽脓肿、根尖性牙周炎、智齿周围炎、拔牙后感染； 睑腺炎、睑炎、急性泪囊炎； 毛囊炎、疖、丹毒、蜂窝组织炎、脓疱病、痈、痤疮感染、皮下脓肿、创伤感染、乳腺炎、淋巴管炎等。',
#        '敏感细菌不产β内酰胺酶的菌所致的感染', '高胆固醇血症；冠心病',
#        '1预防静脉血栓栓塞性疾病（预防静脉内血栓形成），特别是与骨科或普通外科手术有关的血栓形成。 2治疗已形成的深静脉栓塞，伴有或不伴有肺栓塞，临床症状不严重， 不包括需要外科手术或溶栓剂治疗的肺栓塞。3 治疗不稳定性心绞痛，与阿司匹林合用。 4 用于血液透析体外循环中，防止血栓形成。',
#        '原发性高胆固醇血症（Ⅱa型，包括杂合子家族性高胆固醇血症）、混合型血脂异常症（Ⅱb型）',
#        '吗替麦考酚酯适用于接受同种异体肾脏或肝脏移植的患者中预防器官的排斥反应。吗替麦考酚酯应该与环孢素A或他克莫司和皮质类固醇同时应用。',
#        '新生血管性年龄相关性黄斑变性（湿性AMD）患者', '适用于晚期实体瘤的治疗',
#        '本品适用于病毒复制活跃，血清转氨酶ALT持续升高或肝脏组织学显示有活动性病变的慢性成人乙型肝炎的治疗。', '治疗高血脂',
#        '高血压，冠心病', '各种类型的高血压及心绞痛。', '转移性去势抵抗性前列腺癌', '甲型血友病的预防治疗',
# ...

# %%
df.recruitment_status.str.split('|', expand=True)[0].value_counts().plot.bar()
